# %%
import glob
import os

# %%
toclean = os.path.join(os.getcwd(),'training', 'no')
#toclean =  os.path.join(os.getcwd(),'alzheimer','train','ModerateDemented')


files = glob.glob(toclean + '//*.*')
output =  os.path.join(os.getcwd(),'brain_strp')

from functions import brainstrip
import matplotlib.image as img
from tqdm import tqdm
import matplotlib.pyplot as plt
from PIL import Image
from skimage.filters  import threshold_otsu
from skimage.morphology import disk
import numpy as np
import skimage.morphology as morph

for file in tqdm(files[0:10]):
    fname = file.split('\\')[-1]
    print(fname)
    inim = img.imread(file)
    dimn = inim.shape

    if len(dimn) > 2:
        inim = inim[:,:,0]

    th = threshold_otsu(inim)
    binim1 = inim > 15


    print(th)

    eroded_image = morph.erosion(binim1, disk(1))

    plt.imshow(np.where(eroded_image == 1, inim, 0))
    plt.show()

    #plt.imshow(brainstrip(image))
    #plt.show()
    #onlybrain = Image.fromarray(brainstrip(image))
    #display(onlybrain)
    #onlybrain.save(os.path.join(output, fname))
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# 1 no.jpeg
# 35
#  10%|█         | 1/10 [00:00<00:01,  4.91it/s]
# 10 no.jpg
# 46
#  20%|██        | 2/10 [00:00<00:01,  5.94it/s]
# 11 no.jpg
# 42
#  30%|███       | 3/10 [00:00<00:01,  6.07it/s]
# 12 no.jpg
# 53
#  40%|████      | 4/10 [00:00<00:01,  5.82it/s]
# 13 no.jpg
# 51
#  50%|█████     | 5/10 [00:00<00:00,  6.20it/s]
# 14 no.jpg
# 91
#  60%|██████    | 6/10 [00:01<00:00,  5.83it/s]
# 15 no.jpg
# 74
#  70%|███████   | 7/10 [00:01<00:00,  5.91it/s]
# 17 no.jpg
# 56
#  80%|████████  | 8/10 [00:01<00:00,  6.17it/s]
# 18 no.jpg
# 55
#  90%|█████████ | 9/10 [00:01<00:00,  6.29it/s]
# 19 no.jpg
# 77
# 100%|██████████| 10/10 [00:01<00:00,  6.17it/s]
